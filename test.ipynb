# %% [markdown]
# # Smetric Insights  testing code

# %%
import requests
# from urllib.request import Request, urlopen
import json
import hashlib
from PyUnleashed import API

import hmac
import sys
import codecs
import pandas as pd
import time
import datetime

# %%
firefox_headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:23.0) Gecko/20100101 Firefox/23.0'}
urlParam =  "?"
url = "https://api.unleashedsoftware.com/"+ "Customers" + urlParam
apiId = "c4fb1319-bdb7-4c45-9097-2cf3ac5d46ba"
apiKey = '5hCLep58jP3phwoCnPvnRrBrXVyILNbB7CttxOwWxVGZg8Eg4Dcv50RkFjYUDyGlrPkRYRmfyMKpT27u5WrMQ=='

# %%
unlapi =  API(
            url = 'https://api.unleashedsoftware.com/',
            api_id = 'c4fb1319-bdb7-4c45-9097-2cf3ac5d46ba',
            api_key = '5hCLep58jP3phwoCnPvnRrBrXVyILNbB7CttxOwWxVGZg8Eg4Dcv50RkFjYUDyGlrPkRYRmfyMKpT27u5WrMQ=='
)

# %%
res = unlapi.get("Products").json()['Items']
df = pd.DataFrame(data=res)
df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]
df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]
df.to_csv("Products.csv")
df.head()
# Out:
#   ProductCode ProductDescription Barcode PackSize Width Height Depth Weight  \
# 0   BOOKSHELF   Wooden Bookshelf    None     None  None   None  None   None
# 1       CHAIR       Lounge Chair    None     None  None   None  None   None
# 2      COUCH2     2-Seater Couch    None     None  None   None  None   None
# 3      COUCH3     3-Seater Couch    None     None  None   None  None   None
# 4      DINING       Dining Table    None     None  None   None  None   None
#
#    MinStockAlertLevel  MaxStockAlertLevel  ... CreatedBy  \
# 0                 NaN                 NaN  ...     admin
# 1                 2.0                10.0  ...     admin
# 2                10.0                60.0  ...     admin
# 3                 NaN                 NaN  ...     admin
# 4                 NaN                 NaN  ...     admin
#
#                 CreatedOn  LastModifiedBy  CommerceCode  CustomsDescription  \
# 0 2019-06-16 13:02:13.916            None          None                None
# ...

# %%
res = unlapi.get("Customers").json()['Items']
df = pd.DataFrame(data=res)
df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]
df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]
df.to_csv("Customers.csv")
df.head()
# Out:
#   Addresses Contacts TaxCode TaxRate CustomerCode  \
# 0        []       []            None       BENEMP
# 1        []       []            None        EMWAR
# 2        []       []            None       FRANCK
# 3        []       []            None       GAR123
# 4        []       []            None         GBRO
#
#                         CustomerName GSTVATNumber BankName BankBranch  \
# 0                     Ben's Emporium         None     None       None
# 1      Emmanuel's Discount Warehouse         None     None       None
# 2                       Franck & Co.         None     None       None
# 3                       Garrick Inc.         None     None       None
# 4  Griffin Brothers Fabrication Ltd.         None     None       None
#
#   BankAccount  ... CustomerType           PaymentTerm ContactFirstName  \
# 0        None  ...   On Account  20th Month following             None
# 1        None  ...    Wholesale  20th Month following             None
# ...

# %%
res = unlapi.get("PurchaseOrders").json()['Items']
df = pd.DataFrame(data=res)
df['OrderDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['OrderDate']]
df['RequiredDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['RequiredDate']]
df['DeliveryDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['DeliveryDate']]
df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]
df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]


df.to_csv("PurchaseOrders.csv")
df.head()
# Out:
#    OrderNumber               OrderDate        RequiredDate  \
# 0  PO-00000001 2019-06-16 13:02:13.916 2019-06-16 12:00:00
# 1  PO-00000002 2019-06-20 13:02:13.916 2019-06-20 12:00:00
# 2  PO-00000003 2019-06-21 13:02:13.916 2019-06-21 12:00:00
# 3  PO-00000004 2019-06-21 13:02:13.916 2019-06-21 12:00:00
# 4  PO-00000005 2019-06-22 13:02:13.916 2019-06-22 12:00:00
#
#          DeliveryDate CompletedDate  \
# 0 2019-06-16 12:00:00          None
# 1 2019-06-20 12:00:00          None
# 2 2019-06-21 12:00:00          None
# 3 2019-06-21 12:00:00          None
# 4 2019-06-22 12:00:00          None
#
#                                             Supplier SupplierRef Comments  \
# 0  {'Guid': 'cf966a19-db06-4e2e-a1d0-e0d065b85fac...        None     None
# 1  {'Guid': '7dc6dde2-7c66-4537-82df-5796f326ab20...        None     None
# 2  {'Guid': 'd0ed3bac-fa69-46e8-8493-7849eca79561...        None     None
# 3  {'Guid': 'fb61ebe2-b55f-48ee-b1af-cd4c804b7608...        None     None
# ...

# %%
res = unlapi.get("AttributeSets").json()['Items']
df = pd.DataFrame(data=res)
# df['CreatedOn']= [ for i in  df['CreatedOn']]
# df['OrderDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['OrderDate']]
# df['RequiredDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['RequiredDate']]
# df['DeliveryDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['DeliveryDate']]
# df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]
# df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]


# df.to_csv("PurchaseOrders.csv")
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
res = unlapi.get("BillOfMaterials").json()['Items']
df = pd.DataFrame(data=res)

df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]
df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]


df.to_csv("BillOfMaterials.csv")
df.head()
# Out:
#      BillNumber  CanAutoAssemble  CanAutoDisassemble  SortByProductCode  \
# 0  BOM-00000001             True               False               True
#
#                                              Product  \
# 0  {'ProductCode': 'BOOKSHELF', 'ProductDescripti...
#
#                                 BillOfMaterialsLines  TotalCost  Obsolete  \
# 0  [{'LineNumber': 1, 'Product': {'ProductCode': ...    1790.71     False
#
#                 CreatedOn CreatedBy LastModifiedBy AssemblyLayoutId  \
# 0 2019-06-16 13:02:13.916     admin          admin             None
#
#                                    Guid          LastModifiedOn
# 0  66be8445-ab6f-40c9-95cd-779ea971f9a8 2019-06-16 13:02:13.916

# %%
res = unlapi.get("SalesOrders").json()['Items']
df = pd.DataFrame(data=res)

df['OrderDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['OrderDate']]
df['RequiredDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['RequiredDate']]
df['CompletedDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CompletedDate']]

df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]
df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]


df.to_csv("SalesOrders.csv")
df.head()
# Out:
#                                      SalesOrderLines  OrderNumber  \
# 0  [{'LineNumber': 1, 'LineType': None, 'Product'...  SO-00000123
# 1  [{'LineNumber': 1, 'LineType': None, 'Product'...  SO-00000122
# 2  [{'LineNumber': 1, 'LineType': None, 'Product'...  SO-00000121
# 3  [{'LineNumber': 1, 'LineType': None, 'Product'...  SO-00000120
# 4  [{'LineNumber': 1, 'LineType': None, 'Product'...  SO-00000119
#
#                 OrderDate            RequiredDate           CompletedDate  \
# 0 2021-06-14 13:02:13.916 2021-06-14 13:02:13.916 2021-06-14 13:02:13.916
# 1 2021-06-13 13:02:13.916 2021-06-13 13:02:13.916 2021-06-13 13:02:13.916
# 2 2021-06-10 13:02:13.916 2021-06-10 13:02:13.916 2021-06-10 13:02:13.916
# 3 2021-06-08 13:02:13.916 2021-06-08 13:02:13.916 2021-06-08 13:02:13.916
# 4 2021-06-05 13:02:13.916 2021-06-05 13:02:13.916 2021-06-05 13:02:13.916
#
#   OrderStatus                                           Customer CustomerRef  \
# ...

# %%
res = unlapi.get("Salespersons").json()['Items']
df = pd.DataFrame(data=res)
df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]

df.to_csv("Salespersons.csv")
df.head()
# Out:
#      FullName                             Email  Obsolete  \
# 0  John Smith  johh.smith@unleashedsoftware.com     False
#
#                                    Guid          LastModifiedOn
# 0  b4e75e09-b480-4599-a327-2a6517e3ef4f 2019-06-16 13:02:13.916

# %%
res = unlapi.get("SalesShipments").json()['Items']
df = pd.DataFrame(data=res)

df['DispatchDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['DispatchDate']]
df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]

df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]

df.to_csv("SalesShipments.csv")
df.head()
# Out:
#    OrderNumber                             OrderGuid ShipmentNumber  \
# 0  SO-00000123  9c659435-20b7-4a3d-b05d-707e6b47b0ef    SS-00000123
# 1  SO-00000122  80dc68b6-5050-4f4f-a617-8ed5aa838a03    SS-00000122
# 2  SO-00000121  5d0ee858-ac92-4eb1-8500-ed6f3e04d3b0    SS-00000121
# 3  SO-00000120  0cb4d99e-088b-4ea2-a2c9-ceba78d6345d    SS-00000120
# 4  SO-00000119  cc80a652-4efc-4235-92d2-e31b316c7e8a    SS-00000119
#
#   ShipmentStatus        DispatchDate TrackingNumber ShippingCompany Comments  \
# 0     Dispatched 2021-06-14 12:00:00           None            None     None
# 1     Dispatched 2021-06-13 12:00:00           None            None     None
# 2     Dispatched 2021-06-10 12:00:00           None            None     None
# 3     Dispatched 2021-06-08 12:00:00           None            None     None
# 4     Dispatched 2021-06-05 12:00:00           None            None     None
#
#                 CreatedOn CreatedBy LastModifiedBy  \
# ...

# %%
res = unlapi.get("StockAdjustments").json()['Items']
df = pd.DataFrame(data=res)

df['AdjustmentDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['AdjustmentDate']]
df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]

df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]

df.to_csv("StockAdjustments.csv")
df.head()
# Out:
#   AdjustmentNumber                                          Warehouse  \
# 0      SA-00000001  {'WarehouseCode': 'MAIN', 'WarehouseName': 'Ma...
#
#            AdjustmentDate AdjustmentReason     Status  \
# 0 2019-06-26 13:02:13.916    End of Season  Completed
#
#                                 StockAdjustmentLines ConfirmedOn ConfirmedBy  \
# 0  [{'LineNumber': 1, 'Product': {'Guid': '7b0eda...        None        None
#
#   AccountCode               CreatedOn CreatedBy LastModifiedBy  \
# 0             2019-06-26 13:02:13.916     admin          admin
#
#                                    Guid          LastModifiedOn
# 0  23455c4f-1ef9-460d-b3c8-d7701b57f401 2019-06-26 13:02:13.916

# %%
res = unlapi.get("Assemblies").json()['Items']
df = pd.DataFrame(data=res)

df['AssemblyDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['AssemblyDate']]
df['CreatedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['CreatedOn']]

df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]

df.to_csv("Assemblies.csv")
df.head()
# Out:
#   AssemblyNumber           AssemblyDate AssemblyType AssemblyStatus  \
# 0   ASM-00000005  /Date(1622682133916)/     Assembly      Completed
# 1   ASM-00000004  /Date(1622422933916)/     Assembly      Completed
# 2   ASM-00000003  /Date(1620522133916)/     Assembly      Completed
# 3   ASM-00000002  /Date(1620003733916)/     Assembly      Completed
# 4   ASM-00000001  /Date(1615856533916)/     Assembly      Completed
#
#    AutoAssembly  Quantity                          Comments  \
# 0          True       1.0  Created for Invoice SO-00000118.
# 1          True       5.0  Created for Invoice SO-00000117.
# 2          True       5.0  Created for Invoice SO-00000110.
# 3          True       7.0  Created for Invoice SO-00000109.
# 4          True       1.0  Created for Invoice SO-00000101.
#
#    CanAssembleQuantity BatchNumbers SerialNumbers  ...     Total TotalCost  \
# 0                 13.8         None          None  ...   1790.71   1790.71
# ...

# %%
res = unlapi.get("Invoices").json()['Items']
df = pd.DataFrame(data=res)

df['InvoiceDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['InvoiceDate']]
df['DueDate'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['DueDate']]

df['LastModifiedOn'] = [datetime.datetime.fromtimestamp(int(i[1:-1].replace('Date','')[1:-1])/1000) for i in  df['LastModifiedOn']]

df.to_csv("Invoices.csv")
df.head()
# Out:
#   InvoiceNumber  OrderNumber QuoteNumber             InvoiceDate  \
# 0   SI-00000123  SO-00000123        None 2021-06-14 13:02:13.916
# 1   SI-00000122  SO-00000122        None 2021-06-13 13:02:13.916
# 2   SI-00000121  SO-00000121        None 2021-06-10 13:02:13.916
# 3   SI-00000120  SO-00000120        None 2021-06-08 13:02:13.916
# 4   SI-00000119  SO-00000119        None 2021-06-05 13:02:13.916
#
#                   DueDate InvoiceStatus  \
# 0 2021-07-14 13:02:13.916     Completed
# 1 2021-07-13 13:02:13.916     Completed
# 2 2021-07-10 13:02:13.916     Completed
# 3 2021-07-08 13:02:13.916     Completed
# 4 2021-07-05 13:02:13.916     Completed
#
#                                             Customer Comments PostalAddress  \
# 0  {'CustomerCode': 'GAR123', 'CustomerName': 'Ga...     None          None
# 1  {'CustomerCode': 'SIREEN', 'CustomerName': 'Th...     None          None
# 2  {'CustomerCode': 'BENEMP', 'CustomerName': 'Be...     None          None
# ...
